# %% [markdown]
# # Unit 12 - Tales from the Crypto
#
# ---

# %% [markdown]
# ## 1. Sentiment Analysis
#
# Use the [newsapi](https://newsapi.org/) to pull the latest news articles for Bitcoin and Ethereum and create a DataFrame of sentiment scores for each coin.
#
# Use descriptive statistics to answer the following questions:
# 1. Which coin had the highest mean positive score?
# 2. Which coin had the highest negative score?
# 3. Which coin had the highest positive score?

# %%
# Initial imports
import os
import pandas as pd
from dotenv import load_dotenv
import nltk as nltk
nltk.download('vader_lexicon')
from nltk.sentiment.vader import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()
from newsapi.newsapi_client import NewsApiClient

# %matplotlib inline
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
# Read your api key environment variable
# YOUR CODE HERE!
news_api_key = os.getenv("NEWS_API_KEY")

print(f"News API Key type is : {type(news_api_key)}")
# Out:
# News API Key type is : <class 'str'>

# %%
# Create a newsapi client
# YOUR CODE HERE!
news_api = NewsApiClient(api_key=news_api_key)

news_api

# %%
# Fetch the Bitcoin news articles
# YOUR CODE HERE!
btc_news = news_api.get_everything(q="bitcoin",language='en')

# %%
# Summary of BTC news
print(f"An example summary of BTC news: \n"
      f"\n"
      f"{btc_news['articles'][0]}")
print()
print(f"Total number of articles received : {btc_news['totalResults']}")
# Out:
# An example summary of BTC news:
#
# {'source': {'id': 'wired', 'name': 'Wired'}, 'author': 'Paul Ford', 'title': 'A Field Guide for Nature-Resistant Nerds', 'description': 'Yes, yes, the dirt is horrifying. But it’s also how we make bitcoin apps.', 'url': 'https://www.wired.com/story/a-field-guide-for-nature-resistant-nerds-microchips-climate-change/', 'urlToImage': 'https://media.wired.com/photos/61086c497b8c62be3062fe82/191:100/w_1280,c_limit/WI090121_MG_Ford_01.jpg', 'publishedAt': '2021-08-06T11:00:00Z', 'content': 'When my wife started a little garden in our urban backyard, all I could think about were the worms. Also the bugs, and the dirt, which is of course filled with worms and bugs and composted corn cobs.… [+3499 chars]'}
#
# Total number of articles received : 7168

# %%
# Fetch the Ethereum news articles
eth_news = news_api.get_everything(q="ethereum",language="en")

# %%
# Summary of ETH news
print(f"An example summary of ETH news: \n"
      f"\n"
      f"{eth_news['articles'][0]}")
print()
print(f"Total number of articles received : {eth_news['totalResults']}")
# Out:
# An example summary of ETH news:
#
# {'source': {'id': 'techcrunch', 'name': 'TechCrunch'}, 'author': 'Connie Loizos', 'title': 'Crypto investors like Terraform Labs so much, they’re committing $150 million to its ‘ecosystem’', 'description': 'There are many blockchain platforms competing for investors’ and developers’ attention right now, from the big daddy of them all, Ethereum, to so-called “Ethereum Killers” like Solana, which we wrote about in May. Often, these technologies are seen as so prom…', 'url': 'http://techcrunch.com/2021/07/16/crypto-investors-like-terraform-labs-so-much-theyre-committing-150-million-to-its-ecosystem/', 'urlToImage': 'https://techcrunch.com/wp-content/uploads/2020/06/GettyImages-1174590894.jpg?w=667', 'publishedAt': '2021-07-16T16:00:55Z', 'content': 'There are many blockchain platforms competing for investors’ and developers’ attention right now, from the big daddy of them all, Ethereum, to so-called “Ethereum Killers” like Solana, which we wrote… [+2563 chars]'}
#
# Total number of articles received : 2421

# %%
# Create the Bitcoin sentiment scores DataFrame
# YOUR CODE HERE!
btc_sentiments = []

# Get sentiment and append to list
for article in btc_news["articles"]:
    try:
        text = article["content"]
        sentiment = analyzer.polarity_scores(text)
        compound = sentiment["compound"]
        positive = sentiment["pos"]
        negative = sentiment["neg"]
        neutral = sentiment["neu"]
        
        btc_sentiments.append({"text": text,
                               "compound": compound,
                               "positive": positive,
                               "negative": negative,
                               "neutral": neutral})
    except AttributError:
        pass

# %%
# Create sentiment dataframe
btc_sentiments_df = pd.DataFrame(btc_sentiments)

# %%
# Show results

print("Below is the BTC sentiments table preview :")
print()
display(btc_sentiments_df.head())
print()
print("Below is the description of the BTC sentiments table:")
print()
print(btc_sentiments_df.describe())
# Out:
# Below is the BTC sentiments table preview :
#                                                 text  compound  positive  \
# 0  When my wife started a little garden in our ur...   -0.3400     0.000
# 1  Like Dogecoin devotees, the mayor of Reno, and...    0.6908     0.178
# 2  To get a roundup of TechCrunchs biggest and mo...    0.6240     0.127
# 3  While retail investors grew more comfortable b...    0.7264     0.164
# 4  As longtime TechCrunch readers know well, Mich...    0.2732     0.097
#
#    negative  neutral
# 0     0.061    0.939
# 1     0.000    0.822
# 2     0.000    0.873
# 3     0.000    0.836
# 4     0.000    0.903
# Below is the description of the BTC sentiments table:
#
#         compound   positive   negative   neutral
# count  20.000000  20.000000  20.000000  20.00000
# mean    0.048400   0.059400   0.046450   0.89415
# std     0.463778   0.059611   0.083549   0.09326
# min    -0.827100   0.000000   0.000000   0.65300
# 25%    -0.307000   0.000000   0.000000   0.85325
# 50%     0.000000   0.056000   0.000000   0.91050
# 75%     0.445000   0.092500   0.076250   0.95425
# max     0.726400   0.178000   0.287000   1.00000

# %%
# Create the Ethereum sentiment scores DataFrame
# YOUR CODE HERE!
eth_sentiments = []

# %%
# Get sentiment and append to list
for article in eth_news["articles"]:
    try:
        text = article["content"]
        sentiment = analyzer.polarity_scores(text)
        compound = sentiment["compound"]
        positive = sentiment["pos"]
        negative = sentiment["neg"]
        neutral = sentiment["neu"]
        
        eth_sentiments.append({"text": text,
                               "compound": compound,
                               "positive": positive,
                               "negative": negative,
                               "neutral": neutral})
    except AttributError:
        pass

# %%
# Create sentiment dataframe
eth_sentiments_df = pd.DataFrame(eth_sentiments)

# %%
# Show results
print("Below is the ETH sentiments table preview :")
print()
display(eth_sentiments_df.head())
print()
print("Below is the description of the ETH sentiments table:")
print()
print(eth_sentiments_df.describe())
# Out:
# Below is the ETH sentiments table preview :
#                                                 text  compound  positive  \
# 0  There are many blockchain platforms competing ...    0.3612     0.075
# 1  Blockchain infrastructure startups are heating...   -0.2411     0.000
# 2  While retail investors grew more comfortable b...    0.7264     0.164
# 3  Cent was founded in 2017 as an ad-free creator...    0.6956     0.190
# 4  Representation of the Ethereum virtual currenc...    0.0000     0.000
#
#    negative  neutral
# 0     0.000    0.925
# 1     0.061    0.939
# 2     0.000    0.836
# 3     0.000    0.810
# 4     0.000    1.000
# Below is the description of the ETH sentiments table:
#
#         compound   positive  negative   neutral
# count  20.000000  20.000000  20.00000  20.00000
# mean    0.174515   0.056050   0.01345   0.93050
# std     0.312339   0.073898   0.02766   0.08117
# min    -0.340000   0.000000   0.00000   0.78200
# 25%     0.000000   0.000000   0.00000   0.84275
# 50%     0.000000   0.000000   0.00000   0.96950
# 75%     0.402575   0.129500   0.00000   1.00000
# max     0.726400   0.190000   0.07200   1.00000

# %%
# Describe the Bitcoin Sentiment
# YOUR CODE HERE!
print(btc_sentiments_df.describe())
# Out:
#         compound   positive   negative   neutral
# count  20.000000  20.000000  20.000000  20.00000
# mean    0.048400   0.059400   0.046450   0.89415
# std     0.463778   0.059611   0.083549   0.09326
# min    -0.827100   0.000000   0.000000   0.65300
# 25%    -0.307000   0.000000   0.000000   0.85325
# 50%     0.000000   0.056000   0.000000   0.91050
# 75%     0.445000   0.092500   0.076250   0.95425
# max     0.726400   0.178000   0.287000   1.00000

# %%
# Describe the Ethereum Sentiment
# YOUR CODE HERE!
print(eth_sentiments_df.describe())
# Out:
#         compound   positive  negative   neutral
# count  20.000000  20.000000  20.00000  20.00000
# mean    0.174515   0.056050   0.01345   0.93050
# std     0.312339   0.073898   0.02766   0.08117
# min    -0.340000   0.000000   0.00000   0.78200
# 25%     0.000000   0.000000   0.00000   0.84275
# 50%     0.000000   0.000000   0.00000   0.96950
# 75%     0.402575   0.129500   0.00000   1.00000
# max     0.726400   0.190000   0.07200   1.00000

# %% [markdown]
# ### Questions:
#
# Q: Which coin had the highest mean positive score?
#
# A: Ethereum
#
# Q: Which coin had the highest compound score?
#
# A: They were the same
#
# Q. Which coin had the highest positive score?
#
# A: Ethereum

# %% [markdown]
# ---

# %% [markdown]
# ## 2. Natural Language Processing
# ---
# ###   Tokenizer
#
# In this section, you will use NLTK and Python to tokenize the text for each coin. Be sure to:
# 1. Lowercase each word.
# 2. Remove Punctuation.
# 3. Remove Stopwords.

# %%
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer, PorterStemmer
from string import punctuation
import re

# %%
# Instantiate the lemmatizer
# YOUR CODE HERE!
lemmatizer = WordNetLemmatizer()
# Create a list of stopwords
# YOUR CODE HERE!
sw = set(stopwords.words('english'))
# Expand the default stopwords list if necessary
# YOUR CODE HERE!
sw_addons = ["the", "will", "of", "with"]

# %%
# Complete the tokenizer function
def tokenizer(text):
    """Tokenizes text."""
    
    # Remove the punctuation from text
    regex = re.compile("[^a-zA-Z ]")
    re_clean = regex.sub('', text)
   
    # Create a tokenized list of the words
    words_tokenized = word_tokenize(re_clean)
    
    # Lemmatize words into root words
    lem = [lemmatizer.lemmatize(word) for word in words_tokenized]
   
    # Convert the words to lowercase
    words_lowercase = [word.lower() for word in lem]
    
    # Remove the stop words
    words_str = ' '.join(words_lowercase)
            
    tokens = [word for word in words_lowercase if word not in sw.union(sw_addons)]
    
    return tokens

# %%
# Create a new tokens column for Bitcoin
# YOUR CODE HERE!
btc_tokens_list = []

for text in btc_sentiments_df['text']:
    
    tokenized_text = tokenizer(text)
    
    btc_tokens_list.append(tokenized_text)

# %%
btc_sentiments_df["tokens"] = btc_tokens_list

btc_sentiments_df = btc_sentiments_df[["compound", "positive", "negative", "neutral", "text", "tokens"]] 

btc_sentiments_df.head()
# Out:
#    compound  positive  negative  neutral  \
# 0   -0.3400     0.000     0.061    0.939
# 1    0.6908     0.178     0.000    0.822
# 2    0.6240     0.127     0.000    0.873
# 3    0.7264     0.164     0.000    0.836
# 4    0.2732     0.097     0.000    0.903
#
#                                                 text  \
# 0  When my wife started a little garden in our ur...
# 1  Like Dogecoin devotees, the mayor of Reno, and...
# 2  To get a roundup of TechCrunchs biggest and mo...
# 3  While retail investors grew more comfortable b...
# 4  As longtime TechCrunch readers know well, Mich...
#
#                                               tokens
# 0  [wife, started, little, garden, urban, backyar...
# 1  [like, dogecoin, devotee, mayor, reno, leader,...
# 2  [get, roundup, techcrunchs, biggest, important...
# 3  [retail, investor, grew, comfortable, buying, ...
# 4  [longtime, techcrunch, reader, know, well, mic...

# %%
# Create a new tokens list for Bitcoin across all texts
btc_text = str(list(btc_sentiments_df['text']))

btc_tokens = tokenizer(btc_text)

print(f"An example of BTC word tokens: {btc_tokens[:50]}")

print()

print(f"Total number of BTC word tokens are: {len(btc_tokens)}")
# Out:
# An example of BTC word tokens: ['wife', 'started', 'little', 'garden', 'urban', 'backyard', 'could', 'think', 'worm', 'also', 'bug', 'dirt', 'course', 'filled', 'worm', 'bug', 'composted', 'corn', 'cob', 'char', 'like', 'dogecoin', 'devotee', 'mayor', 'reno', 'leader', 'el', 'salvador', 'aldo', 'baoicchi', 'convinced', 'cryptocurrency', 'future', 'ceo', 'founder', 'canadian', 'scooter', 'maker', 'daymak', 'belief', 'char', 'get', 'roundup', 'techcrunchs', 'biggest', 'important', 'story', 'delivered', 'inbox', 'every']
#
# Total number of BTC word tokens are: 390

# %%
# Create a new tokens column for Ethereum
# YOUR CODE HERE!
eth_tokens_list = []

for text in eth_sentiments_df['text']:
    
    tokenized_text = tokenizer(text)
    
    eth_tokens_list.append(tokenized_text)

# %%
eth_sentiments_df["tokens"] = eth_tokens_list

eth_sentiments_df = eth_sentiments_df[["compound", "positive", "negative", "neutral", "text", "tokens"]] 

eth_sentiments_df.head()
# Out:
#    compound  positive  negative  neutral  \
# 0    0.3612     0.075     0.000    0.925
# 1   -0.2411     0.000     0.061    0.939
# 2    0.7264     0.164     0.000    0.836
# 3    0.6956     0.190     0.000    0.810
# 4    0.0000     0.000     0.000    1.000
#
#                                                 text  \
# 0  There are many blockchain platforms competing ...
# 1  Blockchain infrastructure startups are heating...
# 2  While retail investors grew more comfortable b...
# 3  Cent was founded in 2017 as an ad-free creator...
# 4  Representation of the Ethereum virtual currenc...
#
#                                               tokens
# 0  [many, blockchain, platform, competing, invest...
# 1  [blockchain, infrastructure, startup, heating,...
# 2  [retail, investor, grew, comfortable, buying, ...
# 3  [cent, wa, founded, adfree, creator, network, ...
# 4  [representation, ethereum, virtual, currency, ...

# %%
# Create a new tokens column for Ethereum
# YOUR CODE HERE!

eth_text = str(list(eth_sentiments_df['text']))

eth_tokens = tokenizer(eth_text)

print(f"An example of ETH word tokens: {eth_tokens[:50]}")
        
print()

print(f"The total number of ETH word tokens are: {len(eth_tokens)}")
# Out:
# An example of ETH word tokens: ['many', 'blockchain', 'platform', 'competing', 'investor', 'developer', 'attention', 'right', 'big', 'daddy', 'ethereum', 'socalled', 'ethereum', 'killers', 'like', 'solana', 'wrote', 'char', 'blockchain', 'infrastructure', 'startup', 'heating', 'industry', 'fervor', 'brings', 'developer', 'user', 'space', 'still', 'feel', 'extremely', 'young', 'despite', 'heavy', 'institutional', 'embrace', 'crypto', 'char', 'retail', 'investor', 'grew', 'comfortable', 'buying', 'cryptocurrencies', 'like', 'bitcoin', 'ethereum', 'decentralized', 'application', 'world']
#
# The total number of ETH word tokens are: 388

# %% [markdown]
# ---

# %% [markdown]
# ### NGrams and Frequency Analysis
#
# In this section you will look at the ngrams and word frequency for each coin.
#
# 1. Use NLTK to produce the n-grams for N = 2.
# 2. List the top 10 words for each coin.

# %%
from collections import Counter
from nltk import ngrams

# %%
# Bitcoin Counter
btc_word_count = Counter(btc_tokens)

print(f"Below is the word count: \n"
      f"\n"
      f"{dict(btc_word_count)}")
print()
print(f"These words are the most common : {dict(btc_word_count.most_common(10))}")
# Out:
# Below is the word count:
#
# {'wife': 1, 'started': 1, 'little': 1, 'garden': 1, 'urban': 1, 'backyard': 1, 'could': 1, 'think': 1, 'worm': 2, 'also': 1, 'bug': 2, 'dirt': 1, 'course': 1, 'filled': 1, 'composted': 1, 'corn': 1, 'cob': 1, 'char': 19, 'like': 2, 'dogecoin': 1, 'devotee': 1, 'mayor': 1, 'reno': 1, 'leader': 1, 'el': 1, 'salvador': 1, 'aldo': 1, 'baoicchi': 1, 'convinced': 1, 'cryptocurrency': 2, 'future': 1, 'ceo': 1, 'founder': 1, 'canadian': 1, 'scooter': 1, 'maker': 2, 'daymak': 1, 'belief': 1, 'get': 3, 'roundup': 1, 'techcrunchs': 1, 'biggest': 1, 'important': 1, 'story': 1, 'delivered': 1, 'inbox': 1, 'every': 1, 'day': 1, 'pm': 1, 'pdt': 1, 'subscribe': 1, 'herernhello': 1, 'welcome': 1, 'daily': 1, 'crunch': 1, 'july': 5, 'retail': 1, 'investor': 1, 'grew': 1, 'comfortable': 1, 'buying': 1, 'cryptocurrencies': 3, 'bitcoin': 10, 'ethereum': 3, 'decentralized': 1, 'application': 1, 'world': 3, 'still': 1, 'ha': 2, 'lot': 1, 'work': 1, 'come': 1, 'onboarding': 1, 'longtime': 1, 'techcrunch': 2, 'reader': 1, 'know': 1, 'well': 2, 'michael': 1, 'arrington': 1, 'cofounded': 1, 'crunchbase': 1, 'venture': 1, 'fund': 1, 'crunchfund': 1, 'wa': 3, 'later': 1, 'renamed': 1, 'tuesday': 2, 'capital': 1, 'arringto': 1, 'singapore': 1, 'reuters': 7, 'broke': 1, 'wednesday': 1, 'headed': 1, 'another': 1, 'attempt': 1, 'breaking': 1, 'monthslong': 1, 'range': 1, 'short': 1, 'seller': 1, 'bailed': 1, 'trader': 1, 'drew': 1, 'confidence': 1, 'fr': 1, 'james': 1, 'martincnetrna': 1, 'uk': 1, 'man': 1, 'arrested': 1, 'spain': 1, 'alleged': 1, 'role': 1, 'massive': 1, 'hack': 1, 'highprofile': 1, 'twitter': 1, 'account': 1, 'targeted': 1, 'politiciansxaand': 1, 'celebrity': 1, 'us': 1, 'department': 1, 'justi': 1, 'representation': 2, 'virtual': 3, 'currency': 3, 'seen': 4, 'front': 3, 'stock': 2, 'graph': 2, 'illustration': 5, 'taken': 5, 'november': 2, 'reutersdado': 6, 'ruvicillustrationsingapore': 1, 'reco': 1, 'staffrnfile': 1, 'photo': 1, 'ruvicillustrationrnsingapore': 1, 'ruvicillustrationrnwelcome': 1, 'things': 1, 'opening': 2, 'bell': 1, 'forwarded': 1, 'sign': 2, 'herernmarkets': 1, 'insider': 1, 'selling': 1, 'first': 2, 'nfts': 1, 'detail': 1, 'herernlets': 1, 'opinions': 1, 'expressed': 1, 'entrepreneur': 1, 'contributor': 1, 'ownrni': 1, 'launched': 2, 'business': 3, 'three': 1, 'decade': 1, 'ago': 2, 'recent': 1, 'six': 1, 'month': 2, 'ive': 1, 'invested': 1, 'dozen': 1, 'si': 1, 'representations': 2, 'tesla': 2, 'logo': 1, 'february': 1, 'ruvicjuly': 1, 'electriccar': 1, 'inc': 2, 'tslao': 1, 'w': 1, 'ransomware': 2, 'attack': 5, 'fueled': 1, 'covid': 1, 'pandemic': 1, 'turbulence': 1, 'become': 2, 'major': 1, 'money': 1, 'earner': 1, 'cybercriminals': 1, 'number': 1, 'rising': 1, 'rnthese': 1, 'fileencrypting': 1, 'continu': 1, 'image': 1, 'captionthe': 1, 'group': 1, 'recently': 1, 'demanded': 1, 'huge': 1, 'ransom': 1, 'targeting': 1, 'firm': 1, 'kaseyarnwebsites': 1, 'russianlinked': 1, 'gang': 1, 'blamed': 1, 'hundred': 1, 'circle': 2, 'announced': 1, 'plan': 1, 'public': 1, 'company': 3, 'merge': 1, 'concord': 1, 'acquisition': 1, 'corp': 1, 'spac': 1, 'better': 1, 'known': 1, 'one': 1, 'founding': 1, 'member': 1, 'th': 1, 'london': 1, 'fell': 1, 'lowest': 1, 'almost': 1, 'slumping': 1, 'regulator': 1, 'continued': 1, 'call': 1, 'tighter': 1, 'check': 1, 'cryptocurrenciesrnthe': 1, 'largest': 1, 'staffrnamazon': 1, 'app': 1, 'smartphone': 1, 'ruvicillustrationrnreuters': 1, 'amazoncom': 1, 'monday': 1, 'denied': 1, 'medium': 1, 'report': 1, 'saying': 1, 'posted': 2, 'rntesla': 1, 'likely': 1, 'start': 1, 'taking': 1, 'long': 1, 'see': 1, 'ecoin': 1, 'becoming': 1, 'environmentally': 1, 'sustainable': 1, 'say': 1, 'bos': 1, 'elon': 1, 'musk': 1, 'poster': 1, 'participatingrnamazon': 1, 'job': 1, 'late': 1, 'last': 1, 'week': 1, 'suggested': 1, 'ecommerce': 1, 'giant': 1, 'may': 1, 'considering': 1, 'accepting': 1, 'form': 1, 'paymentrnthe': 1, 'posting': 1, 'sent': 1, 'placed': 1, 'pc': 1, 'motherboard': 1, 'june': 1, 'ruvicillustra ...
#
# These words are the most common : {'char': 19, 'bitcoin': 10, 'reuters': 7, 'reutersdado': 6, 'july': 5, 'illustration': 5, 'taken': 5, 'attack': 5, 'seen': 4, 'get': 3}

# %%
# Generate the Bitcoin N-grams where N=2
# YOUR CODE HERE!
btc_bigrams = Counter(ngrams(btc_tokens,n=2))

print(f"The BTC bigrams: \n"
      f"\n"
      f"{dict(btc_bigrams)}")
# Out:
# The BTC bigrams:
#
# {('wife', 'started'): 1, ('started', 'little'): 1, ('little', 'garden'): 1, ('garden', 'urban'): 1, ('urban', 'backyard'): 1, ('backyard', 'could'): 1, ('could', 'think'): 1, ('think', 'worm'): 1, ('worm', 'also'): 1, ('also', 'bug'): 1, ('bug', 'dirt'): 1, ('dirt', 'course'): 1, ('course', 'filled'): 1, ('filled', 'worm'): 1, ('worm', 'bug'): 1, ('bug', 'composted'): 1, ('composted', 'corn'): 1, ('corn', 'cob'): 1, ('cob', 'char'): 1, ('char', 'like'): 1, ('like', 'dogecoin'): 1, ('dogecoin', 'devotee'): 1, ('devotee', 'mayor'): 1, ('mayor', 'reno'): 1, ('reno', 'leader'): 1, ('leader', 'el'): 1, ('el', 'salvador'): 1, ('salvador', 'aldo'): 1, ('aldo', 'baoicchi'): 1, ('baoicchi', 'convinced'): 1, ('convinced', 'cryptocurrency'): 1, ('cryptocurrency', 'future'): 1, ('future', 'ceo'): 1, ('ceo', 'founder'): 1, ('founder', 'canadian'): 1, ('canadian', 'scooter'): 1, ('scooter', 'maker'): 1, ('maker', 'daymak'): 1, ('daymak', 'belief'): 1, ('belief', 'char'): 1, ('char', 'get'): 1, ('get', 'roundup'): 1, ('roundup', 'techcrunchs'): 1, ('techcrunchs', 'biggest'): 1, ('biggest', 'important'): 1, ('important', 'story'): 1, ('story', 'delivered'): 1, ('delivered', 'inbox'): 1, ('inbox', 'every'): 1, ('every', 'day'): 1, ('day', 'pm'): 1, ('pm', 'pdt'): 1, ('pdt', 'subscribe'): 1, ('subscribe', 'herernhello'): 1, ('herernhello', 'welcome'): 1, ('welcome', 'daily'): 1, ('daily', 'crunch'): 1, ('crunch', 'july'): 1, ('july', 'char'): 1, ('char', 'retail'): 1, ('retail', 'investor'): 1, ('investor', 'grew'): 1, ('grew', 'comfortable'): 1, ('comfortable', 'buying'): 1, ('buying', 'cryptocurrencies'): 1, ('cryptocurrencies', 'like'): 1, ('like', 'bitcoin'): 1, ('bitcoin', 'ethereum'): 2, ('ethereum', 'decentralized'): 1, ('decentralized', 'application'): 1, ('application', 'world'): 1, ('world', 'still'): 1, ('still', 'ha'): 1, ('ha', 'lot'): 1, ('lot', 'work'): 1, ('work', 'come'): 1, ('come', 'onboarding'): 1, ('onboarding', 'char'): 1, ('char', 'longtime'): 1, ('longtime', 'techcrunch'): 1, ('techcrunch', 'reader'): 1, ('reader', 'know'): 1, ('know', 'well'): 1, ('well', 'michael'): 1, ('michael', 'arrington'): 1, ('arrington', 'cofounded'): 1, ('cofounded', 'techcrunch'): 1, ('techcrunch', 'crunchbase'): 1, ('crunchbase', 'well'): 1, ('well', 'venture'): 1, ('venture', 'fund'): 1, ('fund', 'crunchfund'): 1, ('crunchfund', 'wa'): 1, ('wa', 'later'): 1, ('later', 'renamed'): 1, ('renamed', 'tuesday'): 1, ('tuesday', 'capital'): 1, ('capital', 'arringto'): 1, ('arringto', 'char'): 1, ('char', 'singapore'): 1, ('singapore', 'july'): 1, ('july', 'reuters'): 3, ('reuters', 'bitcoin'): 3, ('bitcoin', 'broke'): 1, ('broke', 'wednesday'): 1, ('wednesday', 'headed'): 1, ('headed', 'another'): 1, ('another', 'attempt'): 1, ('attempt', 'breaking'): 1, ('breaking', 'monthslong'): 1, ('monthslong', 'range'): 1, ('range', 'short'): 1, ('short', 'seller'): 1, ('seller', 'bailed'): 1, ('bailed', 'trader'): 1, ('trader', 'drew'): 1, ('drew', 'confidence'): 1, ('confidence', 'fr'): 1, ('fr', 'char'): 1, ('char', 'james'): 1, ('james', 'martincnetrna'): 1, ('martincnetrna', 'uk'): 1, ('uk', 'man'): 1, ('man', 'wa'): 1, ('wa', 'arrested'): 1, ('arrested', 'spain'): 1, ('spain', 'alleged'): 1, ('alleged', 'role'): 1, ('role', 'massive'): 1, ('massive', 'hack'): 1, ('hack', 'highprofile'): 1, ('highprofile', 'twitter'): 1, ('twitter', 'account'): 1, ('account', 'targeted'): 1, ('targeted', 'politiciansxaand'): 1, ('politiciansxaand', 'celebrity'): 1, ('celebrity', 'us'): 1, ('us', 'department'): 1, ('department', 'justi'): 1, ('justi', 'char'): 1, ('char', 'representation'): 1, ('representation', 'virtual'): 2, ('virtual', 'currency'): 3, ('currency', 'bitcoin'): 3, ('bitcoin', 'seen'): 3, ('seen', 'front'): 3, ('front', 'stock'): 2, ('stock', 'graph'): 2, ('graph', 'illustration'): 2, ('illustration', 'taken'): 5, ('taken', 'november'): 2, ('november', 'reutersdado'): 2, ('reutersdado', 'ruvicillustrationsingapore'): 1, ('ruvicillustrationsingapore', 'july ...

# %%
# Ethereum Counter
eth_word_count = Counter(eth_tokens)

print(f"Below is the word count: \n"
      f"\n"
      f"{dict(eth_word_count)}")
print()
print(f"These are the most common: {dict(eth_word_count.most_common(10))}")
# Out:
# Below is the word count:
#
# {'many': 1, 'blockchain': 4, 'platform': 4, 'competing': 1, 'investor': 2, 'developer': 2, 'attention': 1, 'right': 1, 'big': 1, 'daddy': 1, 'ethereum': 15, 'socalled': 1, 'killers': 1, 'like': 4, 'solana': 1, 'wrote': 1, 'char': 20, 'infrastructure': 1, 'startup': 1, 'heating': 1, 'industry': 1, 'fervor': 1, 'brings': 1, 'user': 2, 'space': 1, 'still': 2, 'feel': 1, 'extremely': 1, 'young': 1, 'despite': 1, 'heavy': 1, 'institutional': 1, 'embrace': 1, 'crypto': 2, 'retail': 1, 'grew': 1, 'comfortable': 1, 'buying': 1, 'cryptocurrencies': 5, 'bitcoin': 4, 'decentralized': 2, 'application': 1, 'world': 3, 'ha': 4, 'lot': 1, 'work': 1, 'come': 1, 'onboarding': 1, 'cent': 1, 'wa': 3, 'founded': 1, 'adfree': 1, 'creator': 1, 'network': 3, 'allows': 1, 'offer': 1, 'reward': 1, 'good': 1, 'post': 1, 'comment': 1, 'gifting': 1, 'award': 1, 'reddit': 1, 'representation': 3, 'virtual': 3, 'currency': 3, 'standing': 1, 'pc': 4, 'motherboard': 4, 'seen': 3, 'illustration': 6, 'picture': 2, 'february': 2, 'reutersdado': 5, 'ruvicillustrationnew': 2, 'york': 2, 'aug': 2, 'reuters': 6, 'maj': 1, 'hong': 1, 'kong': 1, 'ether': 1, 'held': 1, 'near': 1, 'twomonth': 1, 'high': 1, 'thursday': 1, 'ahead': 1, 'major': 1, 'adjustment': 1, 'underlying': 1, 'would': 1, 'alter': 1, 'way': 1, 'transaction': 1, 'processedrnthe': 1, 'representations': 4, 'placed': 3, 'taken': 5, 'june': 4, 'ruvicillustrationaug': 1, 'spiked': 1, 'monday': 2, 'amazon': 1, 'listed': 1, 'open': 2, 'job': 1, 'digital': 1, 'product': 2, 'leadxarnamazon': 1, 'known': 1, 'plummeting': 1, 'stock': 1, 'wouldbe': 1, 'rival': 1, 'whenever': 1, 'rumor': 1, 'swirl': 1, 'anthony': 1, 'di': 1, 'iorio': 1, 'cofounder': 1, 'say': 1, 'done': 1, 'cryptocurrency': 3, 'partially': 1, 'personal': 2, 'safety': 1, 'concern': 1, 'report': 1, 'bloomberg': 1, 'story': 1, 'shared': 1, 'slashdot': 1, 'july': 1, 'secondla': 1, 'session': 2, 'transform': 2, 'available': 2, 'ondemand': 2, 'watch': 2, 'nowrnlivepeer': 1, 'raised': 1, 'million': 2, 'video': 1, 'transcoding': 1, 'built': 1, 'blockchainxaits': 1, 'ano': 1, 'article': 2, 'translated': 2, 'spanish': 2, 'edition': 2, 'using': 2, 'ai': 3, 'technology': 2, 'errors': 2, 'may': 3, 'exist': 2, 'due': 2, 'processrnthe': 2, 'firm': 1, 'xoy': 1, 'capital': 1, 'based': 1, 'guadalajara': 1, 'jalisco': 1, 'presented': 1, 'xoycoin': 1, 'first': 1, 'shopify': 1, 'made': 1, 'possible': 1, 'eligible': 1, 'seller': 1, 'sell': 1, 'nfts': 2, 'nonfungible': 2, 'token': 2, 'via': 1, 'whole': 1, 'new': 1, 'ecommerce': 1, 'merchantsrnon': 1, 'nbas': 1, 'chicago': 1, 'bulls': 1, 'la': 1, 'finance': 1, 'insider': 1, 'writes': 1, 'strategy': 1, 'tip': 1, 'help': 1, 'make': 1, 'smart': 1, 'decision': 1, 'money': 1, 'receive': 1, 'small': 1, 'commission': 2, 'partner': 1, 'american': 1, 'express': 1, 'securities': 1, 'exchange': 1, 'cvm': 1, 'body': 1, 'regulates': 1, 'security': 1, 'successful': 1, 'testnet': 1, 'deployement': 1, 'london': 1, 'upgrade': 1, 'ready': 1, 'activated': 1, 'mainnet': 1, 'go': 1, 'live': 1, 'block': 1, 'expected': 1, 'august': 1, 'rnclie': 1, 'nowrnpolygon': 1, 'maker': 2, 'cryptobased': 1, 'set': 1, 'fund': 1, 'project': 1, 'dogecoin': 1, 'ripple': 1, 'litecoin': 1, 'ruvicillustrationfile': 1, 'photornj': 1, 'staffrna': 1, 'among': 1, 'reutersedgar': 1, 'suil': 1, 'front': 1, 'tesla': 2, 'logo': 1, 'ruvicjuly': 1, 'electriccar': 1, 'inc': 1, 'tslao': 1, 'w': 1}
#
# These are the most common: {'char': 20, 'ethereum': 15, 'illustration': 6, 'reuters': 6, 'cryptocurrencies': 5, 'reutersdado': 5, 'taken': 5, 'blockchain': 4, 'platform': 4, 'like': 4}

# %%
# Generate the Ethereum N-grams where N=2
# YOUR CODE HERE!
eth_bigrams = Counter(ngrams(eth_tokens,n=2))

print(f"The ETH bigrams: \n"
      f"\n"
      f"{dict(eth_bigrams)}")
# Out:
# The ETH bigrams:
#
# {('many', 'blockchain'): 1, ('blockchain', 'platform'): 1, ('platform', 'competing'): 1, ('competing', 'investor'): 1, ('investor', 'developer'): 1, ('developer', 'attention'): 1, ('attention', 'right'): 1, ('right', 'big'): 1, ('big', 'daddy'): 1, ('daddy', 'ethereum'): 1, ('ethereum', 'socalled'): 1, ('socalled', 'ethereum'): 1, ('ethereum', 'killers'): 1, ('killers', 'like'): 1, ('like', 'solana'): 1, ('solana', 'wrote'): 1, ('wrote', 'char'): 1, ('char', 'blockchain'): 1, ('blockchain', 'infrastructure'): 1, ('infrastructure', 'startup'): 1, ('startup', 'heating'): 1, ('heating', 'industry'): 1, ('industry', 'fervor'): 1, ('fervor', 'brings'): 1, ('brings', 'developer'): 1, ('developer', 'user'): 1, ('user', 'space'): 1, ('space', 'still'): 1, ('still', 'feel'): 1, ('feel', 'extremely'): 1, ('extremely', 'young'): 1, ('young', 'despite'): 1, ('despite', 'heavy'): 1, ('heavy', 'institutional'): 1, ('institutional', 'embrace'): 1, ('embrace', 'crypto'): 1, ('crypto', 'char'): 1, ('char', 'retail'): 1, ('retail', 'investor'): 1, ('investor', 'grew'): 1, ('grew', 'comfortable'): 1, ('comfortable', 'buying'): 1, ('buying', 'cryptocurrencies'): 1, ('cryptocurrencies', 'like'): 1, ('like', 'bitcoin'): 1, ('bitcoin', 'ethereum'): 3, ('ethereum', 'decentralized'): 1, ('decentralized', 'application'): 1, ('application', 'world'): 1, ('world', 'still'): 1, ('still', 'ha'): 1, ('ha', 'lot'): 1, ('lot', 'work'): 1, ('work', 'come'): 1, ('come', 'onboarding'): 1, ('onboarding', 'char'): 1, ('char', 'cent'): 1, ('cent', 'wa'): 1, ('wa', 'founded'): 1, ('founded', 'adfree'): 1, ('adfree', 'creator'): 1, ('creator', 'network'): 1, ('network', 'allows'): 1, ('allows', 'user'): 1, ('user', 'offer'): 1, ('offer', 'crypto'): 1, ('crypto', 'reward'): 1, ('reward', 'good'): 1, ('good', 'post'): 1, ('post', 'comment'): 1, ('comment', 'like'): 1, ('like', 'gifting'): 1, ('gifting', 'award'): 1, ('award', 'reddit'): 1, ('reddit', 'ethereum'): 1, ('ethereum', 'char'): 1, ('char', 'representation'): 1, ('representation', 'ethereum'): 1, ('ethereum', 'virtual'): 1, ('virtual', 'currency'): 2, ('currency', 'standing'): 1, ('standing', 'pc'): 1, ('pc', 'motherboard'): 4, ('motherboard', 'seen'): 1, ('seen', 'illustration'): 1, ('illustration', 'picture'): 1, ('picture', 'february'): 1, ('february', 'reutersdado'): 2, ('reutersdado', 'ruvicillustrationnew'): 2, ('ruvicillustrationnew', 'york'): 2, ('york', 'aug'): 1, ('aug', 'reuters'): 2, ('reuters', 'maj'): 1, ('maj', 'char'): 1, ('char', 'hong'): 1, ('hong', 'kong'): 1, ('kong', 'aug'): 1, ('reuters', 'ether'): 1, ('ether', 'held'): 1, ('held', 'near'): 1, ('near', 'twomonth'): 1, ('twomonth', 'high'): 1, ('high', 'thursday'): 1, ('thursday', 'ahead'): 1, ('ahead', 'major'): 1, ('major', 'adjustment'): 1, ('adjustment', 'underlying'): 1, ('underlying', 'ethereum'): 1, ('ethereum', 'blockchain'): 1, ('blockchain', 'would'): 1, ('would', 'alter'): 1, ('alter', 'way'): 1, ('way', 'transaction'): 1, ('transaction', 'processedrnthe'): 1, ('processedrnthe', 'char'): 1, ('char', 'representations'): 4, ('representations', 'cryptocurrencies'): 2, ('cryptocurrencies', 'bitcoin'): 2, ('ethereum', 'placed'): 2, ('placed', 'pc'): 3, ('motherboard', 'illustration'): 3, ('illustration', 'taken'): 5, ('taken', 'june'): 4, ('june', 'reutersdado'): 3, ('reutersdado', 'ruvicillustrationaug'): 1, ('ruvicillustrationaug', 'reuters'): 1, ('reuters', 'ethereum'): 2, ('ethereum', 'platform'): 1, ('platform', 'char'): 1, ('char', 'cryptocurrencies'): 1, ('cryptocurrencies', 'spiked'): 1, ('spiked', 'monday'): 1, ('monday', 'amazon'): 1, ('amazon', 'listed'): 1, ('listed', 'open'): 1, ('open', 'job'): 1, ('job', 'digital'): 1, ('digital', 'currency'): 1, ('currency', 'blockchain'): 1, ('blockchain', 'product'): 1, ('product', 'leadxarnamazon'): 1, ('leadxarnamazon', 'known'): 1, ('known', 'plummeting'): 1, ('plummeting', 'stock'): 1, ('stock', 'wouldbe'): 1, ('wouldbe', 'rival'): 1, ('rival', 'whenever'): 1, ('whenever', 'rumo ...

# %%
# Function token_count generates the top 10 words for a given coin
def token_count(tokens, N=10):
    """Returns the top N tokens from the frequency count"""
    return Counter(tokens).most_common(N)

# %%
# Use token_count to get the top 10 words for Bitcoin
# YOUR CODE HERE!
btc_top10_token_count = token_count(btc_tokens)

print(f"These are the top 10 words for BTC: \n"
      f" \n"
      f"{dict(btc_top10_token_count)}")
# Out:
# These are the top 10 words for BTC:
#
# {'char': 19, 'bitcoin': 10, 'reuters': 7, 'reutersdado': 6, 'july': 5, 'illustration': 5, 'taken': 5, 'attack': 5, 'seen': 4, 'get': 3}

# %%
# Use token_count to get the top 10 words for Ethereum
# YOUR CODE HERE!
eth_top10_token_count = token_count(eth_tokens)

print(f"These are the top 10 words for ETH: \n"
      f" \n"
      f"{dict(eth_top10_token_count)}")
# Out:
# These are the top 10 words for ETH:
#
# {'char': 20, 'ethereum': 15, 'illustration': 6, 'reuters': 6, 'cryptocurrencies': 5, 'reutersdado': 5, 'taken': 5, 'blockchain': 4, 'platform': 4, 'like': 4}

# %% [markdown]
# ---

# %% [markdown]
# ### Word Clouds
#
# In this section, you will generate word clouds for each coin to summarize the news for each coin

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import matplotlib as mpl
mpl.rcParams['figure.figsize'] = [20.0, 10.0]

# %%
btc_token_str = ' '.join(btc_tokens)
btc_token_str
# Out:
# 'wife started little garden urban backyard could think worm also bug dirt course filled worm bug composted corn cob char like dogecoin devotee mayor reno leader el salvador aldo baoicchi convinced cryptocurrency future ceo founder canadian scooter maker daymak belief char get roundup techcrunchs biggest important story delivered inbox every day pm pdt subscribe herernhello welcome daily crunch july char retail investor grew comfortable buying cryptocurrencies like bitcoin ethereum decentralized application world still ha lot work come onboarding char longtime techcrunch reader know well michael arrington cofounded techcrunch crunchbase well venture fund crunchfund wa later renamed tuesday capital arringto char singapore july reuters bitcoin broke wednesday headed another attempt breaking monthslong range short seller bailed trader drew confidence fr char james martincnetrna uk man wa arrested spain alleged role massive hack highprofile twitter account targeted politiciansxaand celebrity us department justi char representation virtual currency bitcoin seen front stock graph illustration taken november reutersdado ruvicillustrationsingapore july reuters bitcoin reco char reuters staffrnfile photo representation virtual currency bitcoin seen front stock graph illustration taken november reutersdado ruvicillustrationrnsingapore char reutersdado ruvicillustrationrnwelcome things opening bell wa forwarded sign herernmarkets insider selling first nfts get detail herernlets get char opinions expressed entrepreneur contributor ownrni launched first business three decade ago launched recent business six month ago ive invested dozen si char representations virtual currency bitcoin seen front tesla logo illustration taken february reutersdado ruvicjuly reuters electriccar maker tesla inc tslao w char ransomware attack fueled covid pandemic turbulence become major money earner cybercriminals number attack rising rnthese fileencrypting attack continu char image captionthe group recently demanded huge bitcoin ransom attack targeting firm kaseyarnwebsites russianlinked ransomware gang blamed attack hundred business world char circle ha announced plan become public company cryptocurrency company merge concord acquisition corp spac circle better known one founding member th char london july reuters bitcoin fell tuesday lowest almost month slumping regulator continued call tighter check cryptocurrenciesrnthe world largest char reuters staffrnamazon app seen smartphone illustration taken july reutersdado ruvicillustrationrnreuters amazoncom inc monday denied medium report saying char posted rntesla likely start taking bitcoin long see sign ecoin becoming environmentally sustainable say company bos elon musk poster participatingrnamazon posted job opening late last week suggested ecommerce giant may considering accepting cryptocurrencies form paymentrnthe posting sent char representations cryptocurrencies bitcoin ethereum placed pc motherboard illustration taken june reutersdado ruvicillustrationaug reuters ethereum platform char'

# %%
# Generate the Bitcoin word cloud
# YOUR CODE HERE!
btc_token_str = ' '.join(btc_tokens)

btc_wc = WordCloud().generate(btc_token_str)

plt.imshow(btc_wc)
plt.title("Bitcoin Word Cloud", fontsize=20, fontweight='bold')
# Out:
# Text(0.5, 1.0, 'Bitcoin Word Cloud')

# %%
# Generate the Ethereum word cloud
# YOUR CODE HERE!
eth_token_str = ' '.join(eth_tokens)

etc_wc = WordCloud().generate(eth_token_str)

plt.imshow(etc_wc)
plt.title("Ethereum Word Cloud", fontsize=20, fontweight='bold')
# Out:
# Text(0.5, 1.0, 'Ethereum Word Cloud')

# %% [markdown]
# ---
# ## 3. Named Entity Recognition
#
# In this section, you will build a named entity recognition model for both Bitcoin and Ethereum, then visualize the tags using SpaCy.

# %%
import spacy
from spacy import displacy

# %%
# Download the language model for SpaCy
#!python -m spacy download en_core_web_sm

# %%
# Load the spaCy model
nlp = spacy.load('en_core_web_sm')

# %% [markdown]
# ---
# ### Bitcoin NER

# %%
# Concatenate all of the Bitcoin text together
# YOUR CODE HERE!
btc_text
# Out:
# '[\'When my wife started a little garden in our urban backyard, all I could think about were the worms. Also the bugs, and the dirt, which is of course filled with worms and bugs and composted corn cobs.… [+3499 chars]\', \'Like Dogecoin devotees, the mayor of Reno, and the leaders of El Salvador, Aldo Baoicchi is convinced cryptocurrency is the future. The CEO and founder of Canadian scooter maker Daymak believes this … [+4116 chars]\', \'To get a roundup of TechCrunchs biggest and most important stories delivered to your inbox every day at 3 p.m. PDT, subscribe here.\\r\\nHello and welcome to Daily Crunch for July 23, 2021. Its been an i… [+5456 chars]\', \'While retail investors grew more comfortable buying cryptocurrencies like Bitcoin and Ethereum in 2021, the decentralized application world still has a lot of work to do when it comes to onboarding a… [+2288 chars]\', \'As longtime TechCrunch readers know well, Michael Arrington cofounded TechCrunch and Crunchbase, as well as the venture fund CrunchFund, which was later renamed Tuesday Capital. But In 2017, Arringto… [+12730 chars]\', \'SINGAPORE, July 28 (Reuters) - Bitcoin broke above $40,000 on Wednesday and headed for another attempt at breaking from its monthslong range as short sellers bailed out and traders drew confidence fr… [+351 chars]\', \'James Martin/CNET\\r\\nA UK man was arrested in Spain for his alleged role in a massive hack of high-profile Twitter accounts that targeted politicians\\xa0and celebrities in 2020, the US Department of Justi… [+1397 chars]\', \'A representation of virtual currency bitcoin is seen in front of a stock graph in this illustration taken November 19, 2020. REUTERS/Dado Ruvic/IllustrationSINGAPORE, July 21 (Reuters) - Bitcoin reco… [+497 chars]\', \'By Reuters Staff\\r\\nFILE PHOTO: A representation of virtual currency bitcoin is seen in front of a stock graph in this illustration taken November 19, 2020. REUTERS/Dado Ruvic/Illustration\\r\\nSINGAPORE (… [+410 chars]\', "REUTERS/Dado Ruvic/Illustration\\r\\nWelcome to 10 Things Before the Opening Bell. If this was forwarded to you, sign up here.\\r\\nMarkets Insider is selling its first NFTs. Get the details here.\\r\\nLet\'s get… [+2549 chars]", \'Opinions expressed by Entrepreneur contributors are their own.\\r\\nI launched my first business more than three decades ago. I launched my most recent business six months ago. I’ve invested in dozens si… [+4277 chars]\', \'Representations of virtual currency bitcoin are seen in front of Tesla logo in this illustration taken, February 9, 2021. REUTERS/Dado RuvicJuly 21 (Reuters) - Electric-car maker Tesla Inc (TSLA.O) w… [+711 chars]\', \'Ransomware attacks, fueled by COVID-19 pandemic turbulence, have become a major money earner for cybercriminals, with the number of attacks rising in 2020.\\r\\nThese file-encrypting attacks have continu… [+4082 chars]\', \'image captionThe group recently demanded a huge bitcoin ransom for an attack targeting IT firm Kaseya\\r\\nWebsites for a Russian-linked ransomware gang blamed for attacks on hundreds of businesses world… [+1500 chars]\', \'Circle has announced that it plans to become a public company. The cryptocurrency company will merge with Concord Acquisition Corp, a SPAC. Circle is better known as one of the founding members of th… [+2706 chars]\', "LONDON, July 20 (Reuters) - Bitcoin fell on Tuesday to its lowest in almost a month, slumping below $30,000 as regulators continued calls for tighter checks on cryptocurrencies.\\r\\nThe world\'s largest … [+1100 chars]", \'By Reuters Staff\\r\\nAmazon app is seen on a smartphone in this illustration taken, July 13, 2021. REUTERS/Dado Ruvic/Illustration\\r\\n(Reuters) - Amazon.com Inc on Monday denied a media report saying the … [+1079 chars]\', \'Posted \\r\\nTesla is likely to start taking bitcoin again, as long as it sees signs the e-coin is becoming more environmentally sustainable, says company boss Elon Musk.\', \'22 with 21 posters participat ...

# %%
# Run the NER processor on all of the text
btc_ner = nlp(btc_text)

# Add a title to the document
btc_ner.user_data["title"] = "BTC Named Entity Recognition"

# %%
# Render the visualization
# YOUR CODE HERE!
displacy.render(btc_ner, style='ent')
# Out:
# <span class="tex2jax_ignore"><h2 style="margin: 0">BTC Named Entity Recognition</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">['When my wife started a little garden in our urban backyard, all I could think about were the worms. Also the bugs, and the dirt, which is of course filled with worms and bugs and composted corn cobs.… [+3499 chars]', 'Like Dogecoin devotees, the mayor of
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Reno
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# , and the leaders of
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     El Salvador
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Aldo Baoicchi
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  is convinced cryptocurrency is the future. The CEO and founder of
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Canadian
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  scooter maker
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Daymak
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  believes this … [+4116 chars]', 'To get a roundup of TechCrunchs biggest and most important stories delivered to your inbox
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     every day
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  at
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     3 p.m. PDT
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
# , subscribe here.\r\nHello and welcome to
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Daily Crunch
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  for
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     July 23, 2021
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# . Its been an i… [+5456 chars]', 'While retail investors grew more comfortable buying cryptocurrencies like
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bitcoin and Ethereum
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2021
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , the decentralized application world still has a lot of work to do when it comes to onboarding a… [+2288 chars]', 'As longtime TechCrunch readers know well,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Michael Arrington
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  cofounded
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     TechCrunch
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  and
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Crunchbase
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , as well as the venture fund
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     CrunchFund
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
# , which was later renamed
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tuesday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  Capital. But In
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2017
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , Arringto… [+12730 chars]', 'SINGAPORE,
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     July 28
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  (
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Reuters
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ) - Bitcoin broke above $
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     40,000
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Wednesday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  and headed for another attempt at breaking from its monthslong range as short sellers bailed out and traders drew confidence fr… [+351 chars]', '
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     James Martin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# /CNET\r\nA
# <mark class="entity" style

# %%
# List all Entities
# YOUR CODE HERE!
print(f"These are BTC entities: \n"
      f"\n"
      f"{btc_ner.ents}")
# Out:
# These are BTC entities:
#
# (Reno, El Salvador, Aldo Baoicchi, Canadian, Daymak, every day, 3 p.m. PDT, Daily Crunch, July 23, 2021, Bitcoin and Ethereum, 2021, Michael Arrington, TechCrunch, Crunchbase, CrunchFund, Tuesday, 2017, July 28, Reuters, 40,000, Wednesday, James Martin, UK, Spain, Twitter, 2020, the US Department of Justi, November 19, 2020, REUTERS, Dado Ruvic/IllustrationSINGAPORE, July 21, Reuters, Reuters, November 19, 2020, REUTERS, Dado Ruvic/Illustration\r\nSINGAPORE, REUTERS, Dado Ruvic, 10, the Opening Bell, first, Entrepreneur, first, more than three decades ago, six months ago, dozens, February 9, 2021, REUTERS, Dado, Reuters, Tesla Inc, 2020.\r\nThese, Russian, hundreds, Concord Acquisition Corp, SPAC, LONDON, July 20, Reuters, Tuesday, almost a month, 30,000, Reuters, July 13, 2021, REUTERS, Dado Ruvic, Monday, Elon Musk, 22, 21, late last week, Ethereum, June 29, 2021, REUTERS, Dado Ruvic/IllustrationAug 3, Reuters, Ethereum)

# %% [markdown]
# ---

# %% [markdown]
# ### Ethereum NER

# %%
# Concatenate all of the Ethereum text together
# YOUR CODE HERE!
eth_text
# Out:
# '[\'There are many blockchain platforms competing for investors’ and developers’ attention right now, from the big daddy of them all, Ethereum, to so-called “Ethereum Killers” like Solana, which we wrote… [+2563 chars]\', \'Blockchain infrastructure startups are heating up as industry fervor brings more developers and users to a space that still feels extremely young despite a heavy institutional embrace of the crypto s… [+2468 chars]\', \'While retail investors grew more comfortable buying cryptocurrencies like Bitcoin and Ethereum in 2021, the decentralized application world still has a lot of work to do when it comes to onboarding a… [+2288 chars]\', \'Cent was founded in 2017 as an ad-free creator network that allows users to offer each other crypto rewards for good posts and comments — it’s like gifting awards on Reddit, but with Ethereum. But in… [+6228 chars]\', \'Representation of the Ethereum virtual currency standing on the PC motherboard is seen in this illustration picture, February 3, 2018. REUTERS/Dado Ruvic/IllustrationNEW YORK, Aug 5 (Reuters) - A maj… [+439 chars]\', \'HONG KONG, Aug 5 (Reuters) - Ether held near two-month highs on Thursday ahead of a major adjustment to its underlying ethereum blockchain that would alter the way transactions are processed.\\r\\nThe re… [+1331 chars]\', \'Representations of cryptocurrencies Bitcoin and Ethereum are placed on PC motherboard in this illustration taken, June 29, 2021. REUTERS/Dado Ruvic/IllustrationAug 3 (Reuters) - The Ethereum platform… [+2412 chars]\', \'Cryptocurrencies spiked Monday after Amazon listed an open job for a digital currency and blockchain product lead.\\xa0\\r\\nAmazon is known for plummeting the stocks of would-be rivals whenever rumors swirl… [+1425 chars]\', \'"Anthony Di Iorio, a co-founder of the Ethereum network, says he\\\'s done with the cryptocurrency world, partially because of personal safety concerns," reports Bloomberg, in a story shared by Slashdot… [+1550 chars]\', \'Representations of cryptocurrency Ethereum are placed on PC motherboard in this illustration taken, June 29, 2021. REUTERS/Dado Ruvic/IllustrationNEW YORK, July 30 (Reuters) - Ethereum, the second-la… [+3949 chars]\', \'All the sessions from Transform 2021 are available on-demand now. Watch now.\\r\\nLivepeer has raised $20 million for its decentralized video transcoding network built on the Ethereum blockchain.\\xa0Its ano… [+6544 chars]\', \'This article was translated from our Spanish edition using AI technologies. Errors may exist due to this process.\\r\\nThe firm Xoy Capital , based in Guadalajara, Jalisco, presented Xoycoin , the first … [+3547 chars]\', \'Shopify has made it possible for eligible sellers to sell NFTs (non-fungible tokens) via its platform, which opens up a whole new world for e-commerce merchants.\\r\\nOn Monday, the NBAs Chicago Bulls la… [+2148 chars]\', \'Personal Finance Insider writes about products, strategies, and tips to help you make smart decisions with your money. We may receive a small commission from our partners, like American Express, but … [+5827 chars]\', \'This article was translated from our Spanish edition using AI technologies. Errors may exist due to this process.\\r\\nThe Securities and Exchange Commission (CVM), the body that regulates securities in … [+1015 chars]\', \'After a successful testnet deployement, the London upgrade is now ready to be activated on the Ethereum mainnet. It will go live on block 12 965 000, which is expected between August 3-5, 2021.\\r\\nClie… [+5964 chars]\', \'All the sessions from Transform 2021 are available on-demand now. Watch now.\\r\\nPolygon, a maker of a crypto-based platform for nonfungible tokens (NFTs), has set up a $100 million fund for projects ai… [+8080 chars]\', \'Representations of cryptocurrencies Bitcoin, Ethereum, DogeCoin, Ripple, Litecoin are placed on PC motherboard in this illustration taken, June 29, 2021. REUTERS/Dado Ruvic/Illustration/File Photo\\r\\nJ… [+806 cha ...

# %%
# Run the NER processor on all of the text
# YOUR CODE HERE!
eth_ner = nlp(eth_text)

# Add a title to the document
# YOUR CODE HERE!
eth_ner.user_data["title"] = "ETH Named Entity Recognition "

# %%
# Render the visualization
# YOUR CODE HERE!
displacy.render(eth_ner, style='ent')
# Out:
# <span class="tex2jax_ignore"><h2 style="margin: 0">ETH Named Entity Recognition </h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">['There are many blockchain platforms competing for investors’ and developers’ attention right now, from the big daddy of them all,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ethereum
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , to so-called “
# <mark class="entity" style="background: #f0d0ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ethereum Killers
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">WORK_OF_ART</span>
# </mark>
# ” like
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Solana
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , which we wrote… [+2563 chars]', 'Blockchain infrastructure startups are heating up as industry fervor brings more developers and users to a space that still feels extremely young despite a heavy institutional embrace of the crypto s… [+2468 chars]', 'While retail investors grew more comfortable buying cryptocurrencies like
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bitcoin and Ethereum
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2021
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , the decentralized application world still has a lot of work to do when it comes to onboarding a… [+2288 chars]', 'Cent was founded in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2017
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  as an ad-free creator network that allows users to offer each other crypto rewards for good posts and comments — it’s like gifting awards on
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Reddit
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
# , but with
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ethereum
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# . But in… [+6228 chars]', 'Representation of the
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ethereum
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  virtual currency standing on the PC motherboard is seen in this illustration picture,
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     February 3, 2018
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# .
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     REUTERS
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# /
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Dado Ruvic
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# /IllustrationNEW YORK,
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Aug 5
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  (
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Reuters
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ) - A maj… [+439 chars]', '
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     HONG KONG
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ,
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Aug 5
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  (
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Reuters
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ) - Ether held near
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     two-month
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  highs on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Thursday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  ahead of a major adjustment to its underlying ethereum blockchain that would alter the way transactions are processed.\r\nThe re… [+1331 chars]', 'Representations of cryptocurrencies Bitcoin and
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ethereum
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  are placed on PC motherboard in this illustration taken,
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     June 29, 2021
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# .
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     REUTERS
#     <span style="font-size: 0.8em; font-weight: bold; lin

# %%
# List all Entities
# YOUR CODE HERE!
print(f"These are ETH entities: \n"
      f"\n"
      f"{eth_ner.ents}")
# Out:
# These are ETH entities:
#
# (Ethereum, Ethereum Killers, Solana, Bitcoin and Ethereum, 2021, 2017, Reddit, Ethereum, Ethereum, February 3, 2018, REUTERS, Dado Ruvic, Aug 5, Reuters, HONG KONG, Aug 5, Reuters, two-month, Thursday, Ethereum, June 29, 2021, REUTERS, Dado Ruvic/IllustrationAug 3, Reuters, Ethereum, Monday, Amazon, Anthony Di Iorio, Ethereum, Bloomberg, Slashdot, Ethereum, June 29, 2021, REUTERS, Dado Ruvic, July 30, Reuters, second, $20 million, Ethereum, Spanish, AI, Xoy Capital, Guadalajara, Jalisco, Xoycoin, Monday, Chicago Bulls, American Express, Spanish, AI, this process.\r\nThe Securities and Exchange Commission, London, Ethereum, 12 965 000, August 3-5, $100 million, June 29, 2021, REUTERS, Dado Ruvic/Illustration/File, Reuters, Ethereum, June 14, 2021, REUTERS, Edgar Su/Il, February 9, 2021, REUTERS, Dado, Reuters, Tesla Inc)

# %% [markdown]
# ---
